# %%
# Cell 1 re-run

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Cell 2 re-run

import os

DATASET_DIR = "/content/drive/MyDrive/DataMorphAI/Line detection model/annotation10"
IMAGES_DIR = os.path.join(DATASET_DIR, "images")
ANNOTATIONS_FILE = os.path.join(DATASET_DIR, "result.json")

assert os.path.exists(IMAGES_DIR), f"Image folder not found at {IMAGES_DIR}"
assert os.path.exists(ANNOTATIONS_FILE), f"Annotation file not found at {ANNOTATIONS_FILE}"

print("Dataset paths set successfully.")
print(f"Images directory: {IMAGES_DIR}")
print(f"Annotations file: {ANNOTATIONS_FILE}")

print("\nSample image files:")
for i, file in enumerate(os.listdir(IMAGES_DIR)):
    if i < 5:
        print(file)
# Out:
# Dataset paths set successfully.
# Images directory: /content/drive/MyDrive/DataMorphAI/Line detection model/annotation10/images
# Annotations file: /content/drive/MyDrive/DataMorphAI/Line detection model/annotation10/result.json
#
# Sample image files:
# 88cd0575-ldim2.png
# 1c6a0e8a-ldim1.png
# b023d173-ldim7.png
# 42656a07-ldim4.png
# 98c41c3e-ldim5.png

# %%
# Cell 3 re-run working only for cpu

# !pip uninstall -y torch torchvision torchaudio fastai
# !pip install torch==2.0.1+cu118 torchvision==0.15.2 torchaudio==2.0.2 --index-url https://download.pytorch.org/whl/cu118
# !pip install git+https://github.com/facebookresearch/detectron2.git
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Found existing installation: fastai 2.7.19
# Uninstalling fastai-2.7.19:
#   Successfully uninstalled fastai-2.7.19
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 420.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 90.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 96.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 11.5 MB/s eta 0:00:00
# ...

# %%
# !apt-get update && apt-get install -y build-essential python3.11-dev cmake libomp-dev ninja-build
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
# !pip install -U pip setuptools
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)

# %%
# !pip uninstall -y torch torchvision torchaudio fastai numpy
# Out:
# Found existing installation: torch 2.0.1+cu118
# Uninstalling torch-2.0.1+cu118:
#   Successfully uninstalled torch-2.0.1+cu118
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# Found existing installation: torchvision 0.15.2+cu118
# Uninstalling torchvision-0.15.2+cu118:
#   Successfully uninstalled torchvision-0.15.2+cu118
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# Found existing installation: torchaudio 2.0.2+cu118
# Uninstalling torchaudio-2.0.2+cu118:
#   Successfully uninstalled torchaudio-2.0.2+cu118
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# WARNING: Skipping fastai as it is not installed.
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# Found existing installation: numpy 1.24.4
# Uninstalling numpy-1.24.4:
#   Successfully uninstalled numpy-1.24.4

# %%
# !pip uninstall -y numpy tensorboard
# !pip install --force-reinstall numpy==1.24.4 tensorboard==2.14
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# WARNING: Skipping numpy as it is not installed.
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# Found existing installation: tensorboard 2.14.0
# Uninstalling tensorboard-2.14.0:
#   Successfully uninstalled tensorboard-2.14.0
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# ...
#   Using cached numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# ...
#   Using cached tensorboard-2.14.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached absl_py-2.3.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached grpcio-1.73.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# ...
#   Using cached google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# ...

# %%
import numpy as np
print(np.__version__)  # ✅ should be 1.24.4

import tensorboard
print(tensorboard.__version__)  # ✅ should be 2.14
# Out:
# 1.24.4
# 2.14.0

# %%
import numpy
print("NumPy is installed")
print("Installed version:", numpy.__version__)
# Out:
# NumPy is installed
# Installed version: 1.24.4

# %%
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --index-url https://download.pytorch.org/whl/cu118
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp311-cp311-linux_x86_64.whl (2267.3 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp311-cp311-linux_x86_64.whl (6.1 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp311-cp311-linux_x86_64.whl (4.4 MB)
# ...
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [torchaudio]
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.11/dist-packages)
# ...

# %%
# !git clone https://github.com/facebookresearch/detectron2.git
# %cd detectron2
# !pip install -e .
# Out:
# Cloning into 'detectron2'...
# remote: Enumerating objects: 15880, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 15880 (delta 51), reused 18 (delta 17), pack-reused 15788 (from 4)
# Receiving objects: 100% (15880/15880), 6.45 MiB | 5.51 MiB/s, done.
# Resolving deltas: 100% (11550/11550), done.
# /content/detectron2
# Obtaining file:///content/detectron2
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 29.0 MB/s eta 0:00:00
# ...

# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()
print("Detectron2 installed and ready to use!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4-3651878372.py in <cell line: 0>()
#       1 import detectron2
# ----> 2 from detectron2.utils.logger import setup_logger
#       3 setup_logger()
#       4 print("Detectron2 installed and ready to use!")
#
# ModuleNotFoundError: No module named 'detectron2.utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# 💡 Check essential packages and versions
import importlib, subprocess

def check(name, cmd=None, import_as=None):
    print(f"🔹 {name}:", end=" ")
    try:
        if cmd:  # For system tools like cmake or ninja
            out = subprocess.run(cmd.split(), capture_output=True, text=True)
            print(out.stdout.splitlines()[0])
        else:    # For Python packages
            mod = importlib.import_module(import_as or name)
            print("", getattr(mod, "__version__", "version unknown"))
    except Exception as e:
        print(f"Not found — {e}")

# System tools
check("cmake", "cmake --version")
check("ninja", "ninja --version")

# Python packages
check("numpy")
check("tensorboard")
check("torch")
check("torchvision")
check("torchaudio")
check("detectron2")
# Out:
# 🔹 cmake: cmake version 3.31.6
# 🔹 ninja: Not found — [Errno 2] No such file or directory: 'ninja'
# 🔹 numpy:  2.0.2
# 🔹 tensorboard:  2.18.0
# 🔹 torch:  2.6.0+cu124
# 🔹 torchvision:  0.21.0+cu124
# 🔹 torchaudio:  2.6.0+cu124
# 🔹 detectron2:  0.6

# %%
import json
import os

# Load original
with open('/content/drive/MyDrive/DataMorphAI/Line detection model/train.json', 'r') as f:
    data = json.load(f)

fixed_count = 0
for item in data:
    filename = os.path.basename(item["file_name"])
    item["file_name"] = f"/content/drive/MyDrive/DataMorphAI/Line detection model/annotation10/images/{filename}"
    fixed_count += 1

# Save the corrected version
with open('/content/drive/MyDrive/DataMorphAI/Line detection model/train_fixed.json', 'w') as f:
    json.dump(data, f)

print(f"Fixed paths for {fixed_count} items.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-6-1690616327.py in <cell line: 0>()
#       3
#       4 # Load original
# ----> 5 with open('/content/drive/MyDrive/DataMorphAI/Line detection model/train.json', 'r') as f:
#       6     data = json.load(f)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/DataMorphAI/Line detection model/train.json'

# %%
# cell 4: Rerun

from detectron2.data.datasets import register_coco_instances
from detectron2.data import MetadataCatalog, DatasetCatalog

# Dataset info
DATASET_NAME = "line_detection_dataset"
IMAGES_DIR = "/content/drive/MyDrive/DataMorphAI/Line detection model/annotation10/images"
ANNOTATIONS_FILE = "/content/drive/MyDrive/DataMorphAI/Line detection model/annotation10/result.json"

# Register
register_coco_instances(DATASET_NAME, {}, ANNOTATIONS_FILE, IMAGES_DIR)
metadata = MetadataCatalog.get(DATASET_NAME)
dataset_dicts = DatasetCatalog.get(DATASET_NAME)

# Class label
metadata.set(thing_classes=["line"])

print(f"Registered dataset: {DATASET_NAME}")
print(f"Total images: {len(dataset_dicts)}")
# Out:
# WARNING:detectron2.data.datasets.coco:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
# Registered dataset: line_detection_dataset
# Total images: 11

# %%
# Cell 5

import random
import cv2
import matplotlib.pyplot as plt
from detectron2.utils.visualizer import Visualizer

for d in random.sample(dataset_dicts, 3):
    img_path = d["file_name"]
    img = cv2.imread(img_path)

    if img is None:
        print(f"Error: Could not load image from {img_path}")
        continue

    visualizer = Visualizer(img[:, :, ::-1], metadata=metadata, scale=1.0)
    vis = visualizer.draw_dataset_dict(d)

    plt.figure(figsize=(12, 8))
    plt.imshow(vis.get_image())
    plt.axis("off")
    plt.show()

# %%
# Cell 6 re-run

import os
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2 import model_zoo

cfg = get_cfg()

# Base config: Faster R-CNN with ResNet-50 backbone (pretrained)
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))

cfg.DATASETS.TRAIN = (DATASET_NAME,)
cfg.DATASETS.TEST = ()

cfg.DATALOADER.NUM_WORKERS = 2

# Output directory
cfg.OUTPUT_DIR = "/content/line_detector_output"
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# Pretrained weights
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")

cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 300  # 🔁 you can increase later if needed
cfg.SOLVER.STEPS = []      # no LR decay

cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 64
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # Only "line"

cfg.INPUT.MIN_SIZE_TRAIN = (512,)
cfg.INPUT.MAX_SIZE_TRAIN = 1024
cfg.INPUT.MIN_SIZE_TEST = 512
cfg.INPUT.MAX_SIZE_TEST = 1024

print("Config created")
# Out:
# Config created

# %%
# cell 7

trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [06/23 19:07:50 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
# ...

# %%
import shutil

# Path where the final trained model is saved
trained_model_path = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")

# Destination to keep it safe in your Drive
drive_backup_path = "/content/drive/MyDrive/DataMorphAI/Line detection model/model_final.pth"

# Copy to Drive
shutil.copyfile(trained_model_path, drive_backup_path)

print("Trained model saved to Google Drive at:")
print(drive_backup_path)
# Out:
# Trained model saved to Google Drive at:
# /content/drive/MyDrive/DataMorphAI/Line detection model/model_final.pth

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba4703c9-4536-4d42-a66f-4feb55af4f28" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba4703c9-4536-4d42-a66f-4feb55af4f28">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import os
import cv2
from detectron2.engine import DefaultPredictor
from detectron2.utils.visualizer import Visualizer
import matplotlib.pyplot as plt

# Get uploaded file path
image_path = list(uploaded.keys())[0]

# Load image
image = cv2.imread(image_path)
if image is None:
    raise ValueError(f"Could not load image: {image_path}")

# Set Detectron2 config
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
predictor = DefaultPredictor(cfg)

# Run prediction
outputs = predictor(image)

# Visualize
v = Visualizer(image[:, :, ::-1], metadata=metadata, scale=1.2)
out = v.draw_instance_predictions(outputs["instances"].to("cpu"))

# Show result
plt.figure(figsize=(10, 10))
plt.imshow(out.get_image())
plt.axis("off")
plt.title("Predicted Lines")
plt.show()
# Out:
#      <input type="file" id="files-a26e2155-02e8-4868-b054-9168c1f23de0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a26e2155-02e8-4868-b054-9168c1f23de0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Main for auto cropping multiple images

import os
import cv2
from PIL import Image
import shutil
from detectron2.engine import DefaultPredictor

# Create a temporary folder to hold cropped line images
temp_crop_dir = "/content/line_crops"
os.makedirs(temp_crop_dir, exist_ok=True)

# Crop lines from each uploaded image
for file_name in uploaded.keys():
    print(f"🔍 Processing: {file_name}")

    image = cv2.imread(file_name)
    if image is None:
        print(f"⚠️ Skipping {file_name} (could not load)")
        continue

    # Convert to RGB for PIL
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    pil_image = Image.fromarray(image_rgb)

    # Run prediction
    outputs = predictor(image)
    instances = outputs["instances"].to("cpu")
    boxes = instances.pred_boxes if instances.has("pred_boxes") else None

    if not boxes or len(boxes) == 0:
        print(f"⚠️ No lines found in {file_name}")
        continue

    # Save each cropped line
    for i, box in enumerate(boxes):
        x1, y1, x2, y2 = map(int, box.numpy())
        cropped = pil_image.crop((x1, y1, x2, y2))

        # Unique filename based on original image
        base = os.path.splitext(file_name)[0].replace(" ", "_")
        crop_name = f"{base}_line_{i+1}.png"
        save_path = os.path.join(temp_crop_dir, crop_name)
        cropped.save(save_path)

print(f"\n✅ All lines cropped and saved temporarily to {temp_crop_dir}")

# Zip the folder
shutil.make_archive("line_crops", 'zip', temp_crop_dir)

# Download the zip
from google.colab import files
files.download("line_crops.zip")
# Out:
# 🔍 Processing: img1.png
# 🔍 Processing: img2.png
# 🔍 Processing: img3.png
# 🔍 Processing: img4.png
# 🔍 Processing: img5.png
# 🔍 Processing: img6.png
# 🔍 Processing: img7.png
# 🔍 Processing: img8.png
# 🔍 Processing: img9.png
# 🔍 Processing: img10.png
# 🔍 Processing: img11.png
# 🔍 Processing: img12.png
# 🔍 Processing: img13.png
# 🔍 Processing: img14.png
# 🔍 Processing: img15.png
# 🔍 Processing: img16.png
# 🔍 Processing: img17.png
# 🔍 Processing: img18.png
# 🔍 Processing: img19.png
# 🔍 Processing: img20.png
# 🔍 Processing: img21.png
# 🔍 Processing: img22.png
# 🔍 Processing: img23.png
# 🔍 Processing: img24.png
# 🔍 Processing: img25.png
# 🔍 Processing: img26.png
# 🔍 Processing: img27.png
# 🔍 Processing: img28.png
# 🔍 Processing: img29.png
# 🔍 Processing: img30.png
# 🔍 Processing: img31.png
# 🔍 Processing: img32.png
# 🔍 Processing: img33.png
# 🔍 Processing: img34.png
# 🔍 Processing: img35.png
# 🔍 Processing: img36.png
# 🔍 Processing: img37.png
# 🔍 Processing: img38.png
# ...

# %%
import os
from PIL import Image

# Create output directory
output_dir = "/content/cropped_lines"
os.makedirs(output_dir, exist_ok=True)

# Get boxes from predictions
instances = outputs["instances"].to("cpu")
boxes = instances.pred_boxes if instances.has("pred_boxes") else None

# Convert BGR image (OpenCV) to RGB for PIL
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
pil_image = Image.fromarray(image_rgb)

# Crop and save each line
for i, box in enumerate(boxes):
    # box is already a tensor, just get the coordinates directly
    x1, y1, x2, y2 = map(int, box.numpy())

    # Crop the line
    cropped = pil_image.crop((x1, y1, x2, y2))

    # Save as PNG (or JPG)
    filename = f"line_{i+1}.png"
    save_path = os.path.join(output_dir, filename)
    cropped.save(save_path)

print(f"Saved {len(boxes)} cropped lines in: {output_dir}")
# Out:
# Saved 33 cropped lines in: /content/cropped_lines

# %%
import shutil
from google.colab import files

# Zip the cropped lines folder
shutil.make_archive("cropped_lines", 'zip', "/content/cropped_lines")

# Download the zip file to your local system
files.download("cropped_lines.zip")
